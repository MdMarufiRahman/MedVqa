# %%
# notebooks/01_data_exploration.ipynb  — run this
from datasets import load_from_disk
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
#print(str(Path.home())+"/data/vqa_rad/hf_cache")
import os
cwd = os.getcwd()
parent = os.path.dirname(cwd)
#print(parent)

ds = load_from_disk(str(parent)+"/data/vqa_rad/hf_cache")
train = ds["train"]

print(f"Train: {len(train)}, Test: {len(ds['test'])}")
print(f"Columns: {train.column_names}")
# Expect: image, question, answer, question_type, answer_type

# Check question type distribution
from collections import Counter
# qtypes = Counter(train["question_type"])
# print(qtypes)
# Expect: ABNORMALITY, ORGAN, PLANE, MODALITY, etc.

# Sample a few
for i in range(3):
    sample = train[i]
    print(f"Q: {sample['question']}")
    print(f"A: {sample['answer']}\n")
# Out:
# Train: 1793, Test: 451
# Columns: ['image', 'question', 'answer']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 21
#      17 # Expect: image, question, answer, question_type, answer_type
#      18
#      19 # Check question type distribution
#      20 from collections import Counter
# ---> 21 qtypes = Counter(train["question_type"])
#      22 print(qtypes)
#      23 # Expect: ABNORMALITY, ORGAN, PLANE, MODALITY, etc.
#      24
#      25 # Sample a few
#
# File ~/miniforge3/envs/medvqa/lib/python3.10/site-packages/datasets/arrow_dataset.py:2861, in Dataset.__getitem__(self, key)
#    2859 def __getitem__(self, key):  # noqa: F811
#    2860     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2861     return self._getitem(key)
#
# ...
